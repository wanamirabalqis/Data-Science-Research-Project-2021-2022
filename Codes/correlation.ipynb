# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
#veracity

data = pd.read_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitterclean_veracity.csv", header=0)

X = data.iloc[:, [0,2,3,4,5,6,7]].values
y = data.iloc[:, 1].values

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:,1] = le.fit_transform(X[:,1])

# %%
#Using Pearson Correlation VERACITY
plt.figure(figsize=(12,10))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#sentiment
df = pd.read_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitterclean_sent.csv", header=0)

X = data.iloc[:, [0,1,2,3,5,6,7,8,9]].values
y = data.iloc[:, 4].values

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:,2] = le.fit_transform(X[:,2])

# %%
#Using Pearson Correlation COMP_SCORE
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
data = pd.read_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitterclean_sent.csv", header=0)
data.head()
# Out:
#    no  veracity                                            content    source  \
# 0   1         0  If you can hold your breath without coughing d...  8.50E+17
# 1   2         0  A homemade hand sanitizer made with Titos Vodk...  8.08E+18
# 2   3         0  Gargling with salt water or Vinegar eliminate ...  1.80E+18
# 3   4         0  Patients should avoid taking ibuprofen to reli...  1.99E+18
# 4   5         0  Chinese officials are seeking approval to star...  6.97E+18
#
#    sentiment  reply numbers  retweet numbers  likes numbers  \
# 0          1              2               61             95
# 1          1              3               41             67
# 2         -1              6               39             73
# 3         -1              0                0              0
# 4         -1              0                0              0
#
#                                               scores  compound  comp_score
# ...

# %%
df = pd.DataFrame(data)
df = df.drop(['no', 'source','reply numbers','scores','comp_score'], axis = 1)

df
# Out:
#       veracity                                            content  sentiment  \
# 0            0  If you can hold your breath without coughing d...          1
# 1            0  A homemade hand sanitizer made with Titos Vodk...          1
# 2            0  Gargling with salt water or Vinegar eliminate ...         -1
# 3            0  Patients should avoid taking ibuprofen to reli...         -1
# 4            0  Chinese officials are seeking approval to star...         -1
# ...        ...                                                ...        ...
# 2504         0  telecommunications services in the country wil...         -1
# 2505         0  Gov. Steve Sisolaks activation of the Guard th...          0
# 2506         0                   An officer died from coronavirus         -1
# 2507         0  National Guard is being mobilized for anything...          0
# 2508         1  Thank you for your leadership Mayor Lucas! My ...         -1
#
# ...

# %%
df.to_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitter_final.csv", index = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 text = " ".join(cont.split()[1] for cont in df.content)
#
# NameError: name 'df' is not defined
