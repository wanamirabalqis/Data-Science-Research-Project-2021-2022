# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from wordcloud import WordCloud

# %%
data = pd.read_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitter_false_pos.csv", header=0)
data.head()
# Out:
#    veracity                                            content  sentiment  \
# 0         0  If you can hold your breath without coughing d...          1
# 1         0  A homemade hand sanitizer made with Titos Vodk...          1
# 2         0  The White House sent out text messages in mid-...          1
# 3         0  A major disease outbreak occurred in every ele...          1
# 4         0  A photograph shows a railroad tank car identif...          1
#
#    retweet numbers  likes numbers  compound
# 0               61             95    0.4556
# 1               41             67    0.1531
# 2               30             51    0.0772
# 3               61             95    0.0000
# 4               21             54    0.0000

# %%
data.isna().sum()
# Out:
# veracity           0
# content            0
# sentiment          0
# retweet numbers    0
# likes numbers      0
# compound           0
# dtype: int64

# %%
text = " ".join(cont.split()[1] for cont in data.content)

# %%
#FALSE TWEETS with pos sent
wordcloud1 = WordCloud(collocations = False, background_color = 'white').generate(text)

plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Fake with Neg

d2 = pd.read_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitter_fake_neg.csv", header=0)
d2.head()

text2 = " ".join(cont.split()[1] for cont in d2.content)

wordcloud2 = WordCloud(collocations = False, background_color = 'white').generate(text2)

plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# True with Pos sents

d3 = pd.read_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitter_true_pos.csv", header=0)
d3.head()

text3 = " ".join(cont.split()[1] for cont in d3.content)

wordcloud3 = WordCloud(collocations = False, background_color = 'white').generate(text3)

plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# True with Neg sents

d4 = pd.read_csv(r"C:\Users\wnamr\iCloudDrive\Documents\UM\DSRP\Code\twitter_true_neg.csv", header=0)
d4.head()

text4 = " ".join(cont.split()[0] for cont in d4.content)

wordcloud4 = WordCloud(collocations = False, background_color = 'white').generate(text4)

plt.imshow(wordcloud4, interpolation='bilinear')
plt.axis("off")
plt.show()
